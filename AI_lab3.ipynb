# %% [markdown]
# <a href="https://colab.research.google.com/github/Mostafizur979/Artificial-Intelligence-Lab/blob/main/AI_lab3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv('PriceDataSet.csv')
df.dropna()
print(df.to_string())
# Out:
#     weight  price
# 0        1     10
# 1        2     20
# 2        3     25
# 3        4     40
# 4        5     45
# 5        6     75
# 6        7     90
# 7        8    100
# 8        9    115
# 9       10    120
# 10      11    130
# 11      12    132
# 12      13    140
# 13      14    160
# 14      15    165

# %%
print(pd.options.display.max_rows)
# Out:
# 60

# %%
df.head(10)
# Out:
#    weight  price
# 0       1     10
# 1       2     20
# 2       3     25
# 3       4     40
# 4       5     45
# 5       6     75
# 6       7     90
# 7       8    100
# 8       9    115
# 9      10    120

# %%
df.tail(8)
# Out:
#     weight  price
# 7        8    100
# 8        9    115
# 9       10    120
# 10      11    130
# 11      12    132
# 12      13    140
# 13      14    160
# 14      15    165

# %%
df.corr()
# Out:
#           weight     price
# weight  1.000000  0.989168
# price   0.989168  1.000000

# %%
import matplotlib.pyplot as plt
df.plot(kind = 'scatter', x='weight', y = 'price')
plt.xlabel("Weight of Potato")
plt.ylabel("Price of Potato")
plt.title("Price Prediction")
plt.show()

# %%
df["weight"].plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
import pandas as pd

df = pd.read_csv('a.csv')
print(df.to_string())
# Out:
#     weight  price
# 0      1.0     10
# 1      2.0     20
# 2      3.0     25
# 3      4.0     40
# 4      NaN     45
# 5      6.0     75
# 6      7.0     90
# 7      8.0    100
# 8      9.0    115
# 9     10.0    120
# 10     NaN    130
# 11    12.0    132
# 12    13.0    140
# 13    14.0    160
# 14    15.0    165

# %%
new_df=df.dropna()
print(new_df)
# Out:
#     weight  price
# 0      1.0     10
# 1      2.0     20
# 2      3.0     25
# 3      4.0     40
# 5      6.0     75
# 6      7.0     90
# 7      8.0    100
# 8      9.0    115
# 9     10.0    120
# 11    12.0    132
# 12    13.0    140
# 13    14.0    160
# 14    15.0    165

# %%
new_df=df.fillna(11)
print(new_df)
# Out:
#     weight  price
# 0      1.0     10
# 1      2.0     20
# 2      3.0     25
# 3      4.0     40
# 4     11.0     45
# 5      6.0     75
# 6      7.0     90
# 7      8.0    100
# 8      9.0    115
# 9     10.0    120
# 10    11.0    130
# 11    12.0    132
# 12    13.0    140
# 13    14.0    160
# 14    15.0    165

# %%
x=df['weight'].mean()
new_df=df.fillna(x)
print(new_df)
# Out:
#     weight  price
# 0      1.0     10
# 1      2.0     20
# 2      3.0     25
# 3      4.0     40
# 4      8.0     45
# 5      6.0     75
# 6      7.0     90
# 7      8.0    100
# 8      9.0    115
# 9     10.0    120
# 10     8.0    130
# 11    12.0    132
# 12    13.0    140
# 13    14.0    160
# 14    15.0    165

# %%
x=df['weight'].mode()[0]
new_df=df.fillna(x)
print(x)
print(new_df)
# Out:
# 1.0
#     weight  price
# 0      1.0     10
# 1      2.0     20
# 2      3.0     25
# 3      4.0     40
# 4      1.0     45
# 5      6.0     75
# 6      7.0     90
# 7      8.0    100
# 8      9.0    115
# 9     10.0    120
# 10     1.0    130
# 11    12.0    132
# 12    13.0    140
# 13    14.0    160
# 14    15.0    165

# %%
print(df.duplicated())
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# dtype: bool

# %%
df=pd.read_csv('duplicate.csv')
print(df)
# Out:
#     weight  price
# 0        1     10
# 1        2     20
# 2        3     25
# 3        4     40
# 4        5     45
# 5        6     75
# 6        7     90
# 7        8    100
# 8       10    120
# 9       10    120
# 10      11    130
# 11      12    132
# 12      13    140
# 13      14    160
# 14      15    165

# %%
print(df.duplicated())
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9      True
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# dtype: bool

# %%
new_df=df.drop_duplicates()
print(new_df)
# Out:
#     weight  price
# 0        1     10
# 1        2     20
# 2        3     25
# 3        4     40
# 4        5     45
# 5        6     75
# 6        7     90
# 7        8    100
# 8       10    120
# 10      11    130
# 11      12    132
# 12      13    140
# 13      14    160
# 14      15    165

# %%
df.describe()
# Out:
#           weight       price
# count  14.000000   14.000000
# mean    7.928571   89.428571
# std     4.632067   53.822664
# min     1.000000   10.000000
# 25%     4.250000   41.250000
# 50%     7.500000   95.000000
# 75%    11.750000  131.500000
# max    15.000000  165.000000

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df=pd.read_csv('/content/drive/MyDrive/Machine Learning/weather_data.csv')
print(df.to_string())
# Out:
#          day  temperature  windspeed   event
# 0   1/1/2017         32.0        6.0    Rain
# 1   1/4/2017          NaN        7.0   Sunny
# 2   1/5/2017         28.0        NaN    Snow
# 3   1/6/2017          NaN        7.0     NaN
# 4   1/7/2017         32.0        NaN    Rain
# 5   1/8/2017         31.0        2.0   Sunny
# 6   1/9/2017          NaN        NaN     NaN
# 7  1/10/2017         34.0        8.0  Cloudy
# 8  1/11/2017         40.0       12.0   Sunny

# %%
df.head()
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017         32.0        6.0   Rain
# 1  1/4/2017          NaN        7.0  Sunny
# 2  1/5/2017         28.0        NaN   Snow
# 3  1/6/2017          NaN        7.0    NaN
# 4  1/7/2017         32.0        NaN   Rain

# %%
df.tail()
# Out:
#          day  temperature  windspeed   event
# 4   1/7/2017         32.0        NaN    Rain
# 5   1/8/2017         31.0        2.0   Sunny
# 6   1/9/2017          NaN        NaN     NaN
# 7  1/10/2017         34.0        8.0  Cloudy
# 8  1/11/2017         40.0       12.0   Sunny

# %%
df.shape
# Out:
# (9, 4)

# %%
df.columns
# Out:
# Index(['day', 'temperature', 'windspeed', 'event'], dtype='object')

# %%
df['event']
# Out:
# 0      Rain
# 1     Sunny
# 2      Snow
# 3       NaN
# 4      Rain
# 5     Sunny
# 6       NaN
# 7    Cloudy
# 8     Sunny
# Name: event, dtype: object

# %%
df.isnull()
# Out:
#      day  temperature  windspeed  event
# 0  False        False      False  False
# 1  False         True      False  False
# 2  False        False       True  False
# 3  False         True      False   True
# 4  False        False       True  False
# 5  False        False      False  False
# 6  False         True       True   True
# 7  False        False      False  False
# 8  False        False      False  False

# %%
df.isnull().sum()
# Out:
# day            0
# temperature    3
# windspeed      3
# event          2
# dtype: int64

# %%
new_df=df.fillna(method='ffill')
new_df
# Out:
#          day  temperature  windspeed   event
# 0   1/1/2017         32.0        6.0    Rain
# 1   1/4/2017         32.0        7.0   Sunny
# 2   1/5/2017         28.0        7.0    Snow
# 3   1/6/2017         28.0        7.0    Snow
# 4   1/7/2017         32.0        7.0    Rain
# 5   1/8/2017         31.0        2.0   Sunny
# 6   1/9/2017         31.0        2.0   Sunny
# 7  1/10/2017         34.0        8.0  Cloudy
# 8  1/11/2017         40.0       12.0   Sunny

# %%
new_df.isnull().sum()
# Out:
# day            0
# temperature    0
# windspeed      0
# event          0
# dtype: int64

# %%
new_df=df.fillna(method='bfill')
new_df
# Out:
#          day  temperature  windspeed   event
# 0   1/1/2017         32.0        6.0    Rain
# 1   1/4/2017         28.0        7.0   Sunny
# 2   1/5/2017         28.0        7.0    Snow
# 3   1/6/2017         32.0        7.0    Rain
# 4   1/7/2017         32.0        2.0    Rain
# 5   1/8/2017         31.0        2.0   Sunny
# 6   1/9/2017         34.0        8.0  Cloudy
# 7  1/10/2017         34.0        8.0  Cloudy
# 8  1/11/2017         40.0       12.0   Sunny

# %%
df
# Out:
#          day  temperature  windspeed   event
# 0   1/1/2017         32.0        6.0    Rain
# 1   1/4/2017          NaN        7.0   Sunny
# 2   1/5/2017         28.0        NaN    Snow
# 3   1/6/2017          NaN        7.0     NaN
# 4   1/7/2017         32.0        NaN    Rain
# 5   1/8/2017         31.0        2.0   Sunny
# 6   1/9/2017          NaN        NaN     NaN
# 7  1/10/2017         34.0        8.0  Cloudy
# 8  1/11/2017         40.0       12.0   Sunny

# %%
new_df=df.fillna({
    'temperature': df['temperature'].mean(),
    'windspeed': df['windspeed'].mean(),
    'event': df['event'].mode()[0]
})
new_df
# Out:
#          day  temperature  windspeed   event
# 0   1/1/2017    32.000000        6.0    Rain
# 1   1/4/2017    32.833333        7.0   Sunny
# 2   1/5/2017    28.000000        7.0    Snow
# 3   1/6/2017    32.833333        7.0   Sunny
# 4   1/7/2017    32.000000        7.0    Rain
# 5   1/8/2017    31.000000        2.0   Sunny
# 6   1/9/2017    32.833333        7.0   Sunny
# 7  1/10/2017    34.000000        8.0  Cloudy
# 8  1/11/2017    40.000000       12.0   Sunny

# %%
import matplotlib.pyplot as plt
df = pd.read_csv('/content/drive/MyDrive/Machine Learning/PriceDataSet.csv')

# %%
df
# Out:
#     weight  price
# 0        1     10
# 1        2     20
# 2        3     25
# 3        4     40
# 4        5     45
# 5        6     75
# 6        7     90
# 7        8    100
# 8        9    115
# 9       10    120
# 10      11    130
# 11      12    132
# 12      13    140
# 13      14    160
# 14      15    165

# %%
plt.plot(df['weight'],df['price'],'g')
plt.xlabel('weight')
plt.ylabel('price')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot(df['weight'],df['price'],'o:r')
plt.xlabel('weight')
plt.ylabel('price')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot(df['weight'],df['price'],linestyle = 'dotted')
plt.xlabel('weight')
plt.ylabel('price')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot(df['weight'],df['price'])
plt.xlabel('weight')
plt.ylabel('price')
plt.grid()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot(df['weight'],df['price'])
plt.xlabel('weight')
plt.ylabel('price')
plt.grid(axis='x')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot(df['weight'],df['price'])
plt.xlabel('weight')
plt.ylabel('price')
plt.grid(axis='y',color="g")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot(df['weight'],df['price'])
plt.xlabel('weight')
plt.ylabel('price')
plt.grid(linestyle="dashed")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.scatter(df['weight'],df['price'])
plt.xlabel('weight')
plt.ylabel('price')
plt.grid(linestyle="dashed")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.bar(df['weight'],df['price'])
plt.xlabel('weight')
plt.ylabel('price')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist(df['price'],color="green")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.pie(df['price'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
